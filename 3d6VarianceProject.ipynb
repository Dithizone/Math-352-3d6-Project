# %% [markdown]
# # Demonstrating the Law of Large Numbers
#
# The Law of Large Numbers states that, as the number of
# random trials approaches infinity, the average value
# of all results approaches the calculated probability.
# Simulating infinite trials is physically and temporally
# impossible, but 20 iterations of 10 million dice rolls
# can be pretty close to infinite if we use our imagination.
#
# Anyway, there are nine different dice roll experiments each
# with twenty trials. The number of rolls performed in the
# experiments are:
#
# 1. 1,000
# 2. 5,000
# 3. 10,000
# 4. 50,000
# 5. 100,000
# 6. 500,000
# 7. 1,000,000
# 8. 5,000,000
# 9. 10,000,000
#
# We need to determine the mean and variance of each trial
# (which will be something like 10.5 and 9ish?), and the
# mean and variance of each sum over the twenty trials (which
# will be something like ```sum``` and a value that gets
# smaller and smaller the more total rolls there are).
#
# Initial code:

# %%
from UsefulFunctions import meanandvariance, rollslist, datalist

print('Preparations complete.')
# Out:
# Preparations complete.

# %%
for i in range(12):
    print(f'-----{rollslist[i]} rolls-----')
    meanandvariance(datalist[i], rollslist[i])
    print('')
# Out:
# -----50 rolls-----
# 3 occurs with probability mean 0.2%, variance 0.0007199999999999999, and StDev 0.026832815729997475.
# 4 occurs with probability mean 1.4%, variance 0.00968, and StDev 0.09838699100999074.
# 5 occurs with probability mean 3.3000000000000003%, variance 0.0050199999999999976, and StDev 0.07085195833567338.
# 6 occurs with probability mean 3.3000000000000003%, variance 0.010620000000000001, and StDev 0.10305338422390602.
# 7 occurs with probability mean 6.5%, variance 0.013500000000000002, and StDev 0.11618950038622251.
# 8 occurs with probability mean 10.4%, variance 0.02848, and StDev 0.1687601848778319.
# 9 occurs with probability mean 11.0%, variance 0.023600000000000003, and StDev 0.15362291495737218.
# 10 occurs with probability mean 11.9%, variance 0.04038, and StDev 0.20094775440397436.
# 11 occurs with probability mean 11.7%, variance 0.029019999999999997, and StDev 0.17035257556021863.
# 12 occurs with probability mean 13.3%, variance 0.05862, and StDev 0.24211567483333252.
# 13 occurs with probability mean 9.5%, variance 0.02950000000000001, and StDev 0.1717556403731767.
# 14 occurs with probability mean 8.4%, variance 0.016479999999999995, and StDev 0.1283744522870497.
# 15 occurs with probability mean 5.1%, variance 0.013979999999999996, and StDev 0.1182370500308596.
# 16 occurs with probability mean 2.2%, variance 0.00792, and StDev 0.08899438184514795.
# 17 occurs with probability mean 1.1%, variance 0.0035799999999999994, and StDev 0.05983310120660636.
# 18 occurs with probability mean 0.7%, variance 0.00262, and StDev 0.05118593556827891.
# In trial 1, expectation value is 10.860000000000001 with variance 342.07360000000006.
# In trial 2, expectation value is 10.319999999999999 with variance 340.51840000000004.
# In trial 3, expectation value is 9.7 with variance 350.24.
# In trial 4, expectation value is 10.360000000000001 with variance 340.3136.
# In trial 5, expectation value is 11.46 with variance 354.74559999999997.
# In trial 6, expectation value is 10.66 with variance 340.4096.
# In trial 7, expectation value is 10.940000000000001 with variance 343.0976.
# In trial 8, expectation value is 10.76 with variance 341.0816.
# In trial 9, expectation value is 10.540000000000001 with variance 340.0256.
# In trial 10, expectation value is 10.860000000000001 with variance 342.07360000000006.
# In trial 11, expectation value is 10.32 with variance 340.51839999999993.
# In trial 12, expectation value is 11.020000000000001 with variance 344.32640000000004.
# In trial 13, expectation value is 11.02 with variance 344.32640000000004.
# In trial 14, expectation value is 10.520000000000001 with variance 340.0064.
# In trial 15, expectation value is 10.600000000000001 with variance 340.1600000000001.
# In trial 16, expectation value is 10.18 with variance 341.63840000000005.
# In trial 17, expectation value is 10.44 with variance 340.0576.
# In trial 18, expectation value is 10.1 with variance 342.56000000000006.
# In trial 19, expectation value is 10.240000000000002 with variance 341.0816.
# In trial 20, expectation value is 11.42 with variance 353.5424.
#
# -----100 rolls-----
# 3 occurs with probability mean 0.55%, variance 0.000895, and StDev 0.029916550603303182.
# 4 occurs with probability mean 1.8500000000000003%, variance 0.006254999999999999, and StDev 0.0790885579587844.
# 5 occurs with probability mean 2.8%, variance 0.003919999999999998, and StDev 0.0626099033699941.
# 6 occurs with probability mean 4.65%, variance 0.0066549999999999995, and StDev 0.0815781833580523.
# 7 occurs with probability mean 6.849999999999999%, variance 0.010455, and StDev 0.10224969437607137.
# 8 occurs with probability mean 9.85%, variance 0.015454999999999997, and StDev 0.1243181402692302.
# 9 occurs with probability mean 9.9%, variance 0.015979999999999998, and StDev 0.12641202474448385.
# 10 occurs with probability mean 13.600000000000001%, variance 0.023080000000000003, and StDev 0.15192103211866356.
# 11 occurs with probability mean 12.45%, variance 0.023095000000000004, and StDev 0.15197039185315014.
# 12 occurs with probability mean 11.45%, variance 0.009094999999999999, and StDev 0.09536770941990795.
# 13 occurs with probability mean 9.15%, variance 0.014455, and StDev 0.12022894826122368.
# 14 occurs with probability mean 7.1%, variance 0.009180000000000002, and StDev 0.09581231653602788.
# 15 occurs with probability mean 5.15%, variance 0.015055000000000002, and StDev 0.12269881825021789.
# 16 occurs with probability mean 2.85%, variance 0.010655000000000005, and StDev 0.10322305943925517.
# 17 occurs with probability mean 1.4%, variance 0.0030800000000000003, and StDev 0.055497747702046435.
# 18 occurs with probability mean 0.4%, variance 0.0006799999999999998, and StDev 0.026076809620810593.
# In trial 1, expectation value is 9.75 with variance 349.0.
# In trial 2, expectation value is 10.690000000000001 with variance 340.57759999999996.
# In trial 3, expectation value is 10.56 with variance 340.0575999999999.
# In trial 4, expectation value is 10.15 with variance 341.96000000000004.
# In trial 5, expectation value is 10.41 with variance 340.1296.
# In trial 6, expectation value is 10.810000000000002 with variance 341.53760000000005.
# In trial 7, expectation value is 10.469999999999999 with variance 340.0144.
# In trial 8, expectation value is 10.27 with variance 340.8464.
# In trial 9, expectation value is 11.239999999999998 with variance 348.7616.
# In trial 10, expectation value is 10.169999999999998 with variance 341.74240000000003.
# In trial 11, expectation value is 10.89 with variance 342.4336.
# In trial 12, expectation value is 10.120000000000001 with variance 342.3104.
# In trial 13, expectation value is 10.48 with variance 340.0064.
# In trial 14, expectation value is 10.99 with variance 343.8416.
# In trial 15, expectation value is 10.720000000000002 with variance 340.7744.
# In trial 16, expectation value is 10.38 with variance 340.2304.
# In trial 17, expectation value is 10.17 with variance 341.7424.
# In trial 18, expectation value is 10.25 with variance 341.0.
# In trial 19, expectation value is 10.73 with variance 340.8464.
# In trial 20, expectation value is 10.62 with variance 340.23040000000003.
#
# -----500 rolls-----
# 3 occurs with probability mean 0.47000000000000003%, variance 9.019999999999998e-05, and StDev 0.009497368056467012.
# 4 occurs with probability mean 1.15%, variance 0.00040699999999999986, and StDev 0.020174241001832013.
# 5 occurs with probability mean 2.83%, variance 0.0014342, and StDev 0.03787083310411853.
# 6 occurs with probability mean 4.7%, variance 0.0023160000000000004, and StDev 0.048124837662063866.
# 7 occurs with probability mean 7.5200000000000005%, variance 0.003923199999999999, and StDev 0.06263545321940282.
# 8 occurs with probability mean 10.16%, variance 0.0022048000000000002, and StDev 0.046955297890653405.
# 9 occurs with probability mean 11.86%, variance 0.0025848000000000017, and StDev 0.05084092839435568.
# 10 occurs with probability mean 12.42%, variance 0.002807199999999999, and StDev 0.05298301614668609.
# 11 occurs with probability mean 12.06%, variance 0.0048408, and StDev 0.06957585788188314.
# 12 occurs with probability mean 11.44%, variance 0.004124799999999999, and StDev 0.06422460587656416.
# 13 occurs with probability mean 9.309999999999999%, variance 0.004347799999999999, and StDev 0.06593784952513995.
# 14 occurs with probability mean 6.529999999999999%, variance 0.0025862, and StDev 0.05085469496516521.
# 15 occurs with probability mean 4.45%, variance 0.002879, and StDev 0.05365631370118525.
# 16 occurs with probability mean 2.8000000000000003%, variance 0.0008399999999999999, and StDev 0.028982753492378877.
# 17 occurs with probability mean 1.66%, variance 0.0005048, and StDev 0.02246775467197379.
# 18 occurs with probability mean 0.64%, variance 0.0001328, and StDev 0.011523888232710347.
# In trial 1, expectation value is 10.278 with variance 340.788544.
# In trial 2, expectation value is 10.518000000000002 with variance 340.00518399999993.
# In trial 3, expectation value is 10.533999999999999 with variance 340.0184959999999.
# In trial 4, expectation value is 10.58 with variance 340.10240000000005.
# In trial 5, expectation value is 10.542 with variance 340.02822399999997.
# In trial 6, expectation value is 10.266000000000002 with variance 340.876096.
# In trial 7, expectation value is 10.512000000000002 with variance 340.0023039999999.
# In trial 8, expectation value is 10.600000000000001 with variance 340.1600000000001.
# In trial 9, expectation value is 10.424000000000001 with variance 340.09241599999996.
# In trial 10, expectation value is 10.448000000000002 with variance 340.043264.
# In trial 11, expectation value is 10.562000000000001 with variance 340.061504.
# In trial 12, expectation value is 10.466000000000001 with variance 340.01849599999997.
# In trial 13, expectation value is 10.328 with variance 340.473344.
# In trial 14, expectation value is 10.322000000000001 with variance 340.506944.
# In trial 15, expectation value is 10.394 with variance 340.17977599999995.
# In trial 16, expectation value is 10.564 with variance 340.06553600000007.
# In trial 17, expectation value is 10.908 with variance 342.66342399999996.
# In trial 18, expectation value is 10.45 with variance 340.03999999999996.
# In trial 19, expectation value is 10.350000000000001 with variance 340.35999999999996.
# In trial 20, expectation value is 10.334000000000001 with variance 340.44089599999995.
#
# -----1000 rolls-----
# 3 occurs with probability mean 0.49000000000000005%, variance 7.379999999999999e-05, and StDev 0.00859069263796581.
# 4 occurs with probability mean 1.5099999999999998%, variance 0.0001438, and StDev 0.011991663771137015.
# 5 occurs with probability mean 2.8899999999999997%, variance 0.0008018000000000004, and StDev 0.028316073174082603.
# 6 occurs with probability mean 4.74%, variance 0.0006687999999999999, and StDev 0.02586116780039138.
# 7 occurs with probability mean 6.8500000000000005%, variance 0.0007009999999999997, and StDev 0.026476404589747447.
# 8 occurs with probability mean 9.65%, variance 0.0019190000000000006, and StDev 0.04380639222761903.
# 9 occurs with probability mean 11.615%, variance 0.00226455, and StDev 0.04758728821859889.
# 10 occurs with probability mean 12.475%, variance 0.0023397499999999994, and StDev 0.04837096236379838.
# 11 occurs with probability mean 12.165000000000001%, variance 0.0022065500000000003, and StDev 0.04697392893935955.
# 12 occurs with probability mean 11.540000000000001%, variance 0.0027387999999999996, and StDev 0.05233354564712771.
# 13 occurs with probability mean 9.93%, variance 0.0017702, and StDev 0.042073744782227314.
# 14 occurs with probability mean 7.095%, variance 0.0010309499999999997, and StDev 0.032108410113239796.
# 15 occurs with probability mean 4.545000000000001%, variance 0.00092495, and StDev 0.030412990645446232.
# 16 occurs with probability mean 2.795%, variance 0.0007169500000000002, and StDev 0.026775922019605602.
# 17 occurs with probability mean 1.325%, variance 0.00030175000000000004, and StDev 0.01737095276604021.
# 18 occurs with probability mean 0.385%, variance 7.255000000000004e-05, and StDev 0.008517628778010935.
# In trial 1, expectation value is 10.357999999999999 with variance 340.322624.
# In trial 2, expectation value is 10.421999999999999 with variance 340.097344.
# In trial 3, expectation value is 10.598 with variance 340.153664.
# In trial 4, expectation value is 10.44 with variance 340.0576.
# In trial 5, expectation value is 10.414000000000001 with variance 340.11833599999994.
# In trial 6, expectation value is 10.495000000000001 with variance 340.0004.
# In trial 7, expectation value is 10.513000000000002 with variance 340.002704.
# In trial 8, expectation value is 10.381 with variance 340.226576.
# In trial 9, expectation value is 10.485999999999999 with variance 340.003136.
# In trial 10, expectation value is 10.374 with variance 340.254016.
# In trial 11, expectation value is 10.556999999999999 with variance 340.05198399999995.
# In trial 12, expectation value is 10.586 with variance 340.118336.
# In trial 13, expectation value is 10.396999999999998 with variance 340.16974400000004.
# In trial 14, expectation value is 10.606 with variance 340.179776.
# In trial 15, expectation value is 10.497 with variance 340.0001439999999.
# In trial 16, expectation value is 10.438 with variance 340.0615039999999.
# In trial 17, expectation value is 10.485999999999999 with variance 340.003136.
# In trial 18, expectation value is 10.485000000000001 with variance 340.0036.
# In trial 19, expectation value is 10.485999999999999 with variance 340.003136.
# In trial 20, expectation value is 10.561 with variance 340.059536.
#
# -----5000 rolls-----
# 3 occurs with probability mean 0.479%, variance 3.9078e-05, and StDev 0.006251239877016399.
# 4 occurs with probability mean 1.349%, variance 5.491800000000001e-05, and StDev 0.0074106679860860055.
# 5 occurs with probability mean 2.682%, variance 8.4072e-05, and StDev 0.009169078470598885.
# 6 occurs with probability mean 4.691%, variance 0.000280838, and StDev 0.016758221862715625.
# 7 occurs with probability mean 6.997000000000001%, variance 0.00021466200000000004, and StDev 0.014651348060844095.
# 8 occurs with probability mean 9.77%, variance 0.00031748000000000025, and StDev 0.017817968458833915.
# 9 occurs with probability mean 11.655%, variance 0.0003316699999999997, and StDev 0.018211809355470412.
# 10 occurs with probability mean 12.567%, variance 0.0004916219999999993, and StDev 0.022172550597529355.
# 11 occurs with probability mean 12.45%, variance 0.0006133999999999998, and StDev 0.024766913412857885.
# 12 occurs with probability mean 11.511%, variance 0.0003677180000000002, and StDev 0.019175974551505857.
# 13 occurs with probability mean 9.704%, variance 0.00041460799999999974, and StDev 0.020361925252784907.
# 14 occurs with probability mean 7.004%, variance 0.00018916799999999998, and StDev 0.013753835828597053.
# 15 occurs with probability mean 4.579%, variance 0.00015443799999999996, and StDev 0.012427308638639339.
# 16 occurs with probability mean 2.783%, variance 0.00011498199999999999, and StDev 0.010722966007593234.
# 17 occurs with probability mean 1.331%, variance 4.9157999999999986e-05, and StDev 0.00701127663125625.
# 18 occurs with probability mean 0.44799999999999995%, variance 1.8192000000000005e-05, and StDev 0.004265208084021224.
# In trial 1, expectation value is 10.537800000000002 with variance 340.02286144.
# In trial 2, expectation value is 10.440999999999999 with variance 340.055696.
# In trial 3, expectation value is 10.556200000000002 with variance 340.05053504.
# In trial 4, expectation value is 10.499199999999997 with variance 340.00001024.
# In trial 5, expectation value is 10.525599999999999 with variance 340.01048576000005.
# In trial 6, expectation value is 10.4764 with variance 340.00891136000007.
# In trial 7, expectation value is 10.4864 with variance 340.00295936000003.
# In trial 8, expectation value is 10.470999999999998 with variance 340.013456.
# In trial 9, expectation value is 10.4526 with variance 340.03594816.
# In trial 10, expectation value is 10.5262 with variance 340.01098304.
# In trial 11, expectation value is 10.501600000000002 with variance 340.00004096.
# In trial 12, expectation value is 10.514599999999998 with variance 340.00341056.
# In trial 13, expectation value is 10.422400000000001 with variance 340.09634816.
# In trial 14, expectation value is 10.4602 with variance 340.02534463999996.
# In trial 15, expectation value is 10.464 with variance 340.020736.
# In trial 16, expectation value is 10.532399999999999 with variance 340.01679616.
# In trial 17, expectation value is 10.448799999999999 with variance 340.04194304.
# In trial 18, expectation value is 10.498999999999999 with variance 340.000016.
# In trial 19, expectation value is 10.504800000000001 with variance 340.00036864.
# In trial 20, expectation value is 10.5372 with variance 340.02214144000004.
#
# -----10000 rolls-----
# 3 occurs with probability mean 0.4545%, variance 6.6895e-06, and StDev 0.0025864067738853454.
# 4 occurs with probability mean 1.4015000000000002%, variance 3.2005499999999984e-05, and StDev 0.0056573403645175865.
# 5 occurs with probability mean 2.791%, variance 0.00010595799999999996, and StDev 0.010293590238590226.
# 6 occurs with probability mean 4.7219999999999995%, variance 9.817200000000002e-05, and StDev 0.009908178440056477.
# 7 occurs with probability mean 6.9095%, variance 7.896949999999995e-05, and StDev 0.008886478492631373.
# 8 occurs with probability mean 9.73%, variance 0.00019914000000000002, and StDev 0.014111697275664612.
# 9 occurs with probability mean 11.5475%, variance 0.00017729750000000012, and StDev 0.013315310736141313.
# 10 occurs with probability mean 12.49%, variance 0.00019557999999999989, and StDev 0.013984991955664468.
# 11 occurs with probability mean 12.4795%, variance 0.00011352950000000008, and StDev 0.010655022289981381.
# 12 occurs with probability mean 11.564499999999999%, variance 8.222949999999996e-05, and StDev 0.009068048301591691.
# 13 occurs with probability mean 9.697%, variance 0.00010214200000000007, and StDev 0.010106532540886615.
# 14 occurs with probability mean 6.965000000000001%, variance 0.0001156100000000001, and StDev 0.010752209075348195.
# 15 occurs with probability mean 4.672%, variance 3.421199999999999e-05, and StDev 0.005849102495255147.
# 16 occurs with probability mean 2.7239999999999998%, variance 2.732800000000002e-05, and StDev 0.005227618960865455.
# 17 occurs with probability mean 1.365%, variance 2.660999999999999e-05, and StDev 0.005158488150611571.
# 18 occurs with probability mean 0.48700000000000004%, variance 1.4862000000000004e-05, and StDev 0.0038551264570698593.
# In trial 1, expectation value is 10.5132 with variance 340.00278784.
# In trial 2, expectation value is 10.520400000000002 with variance 340.00665856.
# In trial 3, expectation value is 10.520100000000001 with variance 340.00646416.
# In trial 4, expectation value is 10.4757 with variance 340.00944784.
# In trial 5, expectation value is 10.5155 with variance 340.003844.
# In trial 6, expectation value is 10.544699999999999 with variance 340.03196944.
# In trial 7, expectation value is 10.492500000000001 with variance 340.0009.
# In trial 8, expectation value is 10.439299999999998 with variance 340.05895183999996.
# In trial 9, expectation value is 10.4965 with variance 340.000196.
# In trial 10, expectation value is 10.4645 with variance 340.020164.
# In trial 11, expectation value is 10.5089 with variance 340.00126736.
# In trial 12, expectation value is 10.471400000000001 with variance 340.01308736.
# In trial 13, expectation value is 10.528300000000002 with variance 340.01281423999995.
# In trial 14, expectation value is 10.491999999999999 with variance 340.00102400000003.
# In trial 15, expectation value is 10.4454 with variance 340.04769856.
# In trial 16, expectation value is 10.4849 with variance 340.00364815999995.
# In trial 17, expectation value is 10.497499999999999 with variance 340.00010000000003.
# In trial 18, expectation value is 10.467500000000001 with variance 340.0169.
# In trial 19, expectation value is 10.5054 with variance 340.00046655999995.
# In trial 20, expectation value is 10.5253 with variance 340.01024143999996.
#
# -----50000 rolls-----
# 3 occurs with probability mean 0.4667%, variance 3.7402200000000008e-06, and StDev 0.0019339648393908305.
# 4 occurs with probability mean 1.3817000000000002%, variance 6.193019999999999e-06, and StDev 0.0024885779071590263.
# 5 occurs with probability mean 2.7836999999999996%, variance 1.0211420000000002e-05, and StDev 0.00319553125473684.
# 6 occurs with probability mean 4.6256%, variance 8.834079999999994e-06, and StDev 0.002972218026996.
# 7 occurs with probability mean 6.9259%, variance 1.9193980000000015e-05, and StDev 0.004381093470812968.
# 8 occurs with probability mean 9.777899999999999%, variance 1.214438000000003e-05, and StDev 0.003484878764031832.
# 9 occurs with probability mean 11.5673%, variance 6.442981999999992e-05, and StDev 0.008026818797007935.
# 10 occurs with probability mean 12.4491%, variance 3.987638e-05, and StDev 0.0063147747386585375.
# 11 occurs with probability mean 12.563099999999999%, variance 4.068038e-05, and StDev 0.006378117277065388.
# 12 occurs with probability mean 11.536700000000002%, variance 4.7587420000000006e-05, and StDev 0.006898363574065954.
# 13 occurs with probability mean 9.757%, variance 2.837079999999998e-05, and StDev 0.005326424692042494.
# 14 occurs with probability mean 6.9177%, variance 2.169861999999996e-05, and StDev 0.004658177755303029.
# 15 occurs with probability mean 4.6277%, variance 9.195420000000012e-06, and StDev 0.003032395092991679.
# 16 occurs with probability mean 2.7596%, variance 1.5716480000000006e-05, and StDev 0.003964401594187956.
# 17 occurs with probability mean 1.3902%, variance 3.4967200000000013e-06, and StDev 0.001869951871038397.
# 18 occurs with probability mean 0.4701%, variance 1.5491799999999994e-06, and StDev 0.0012446605963072823.
# In trial 1, expectation value is 10.508780000000002 with variance 340.0012334143999.
# In trial 2, expectation value is 10.481119999999997 with variance 340.0057032704.
# In trial 3, expectation value is 10.509500000000001 with variance 340.001444.
# In trial 4, expectation value is 10.504 with variance 340.000256.
# In trial 5, expectation value is 10.480440000000002 with variance 340.0061214976001.
# In trial 6, expectation value is 10.490040000000002 with variance 340.0015872256.
# In trial 7, expectation value is 10.494519999999998 with variance 340.00048048639997.
# In trial 8, expectation value is 10.493979999999999 with variance 340.0005798464.
# In trial 9, expectation value is 10.49646 with variance 340.00020050559993.
# In trial 10, expectation value is 10.481639999999999 with variance 340.0053934336001.
# In trial 11, expectation value is 10.510980000000002 with variance 340.00192896640004.
# In trial 12, expectation value is 10.514940000000001 with variance 340.0035712576.
# In trial 13, expectation value is 10.51624 with variance 340.0042198016.
# In trial 14, expectation value is 10.503779999999999 with variance 340.0002286144.
# In trial 15, expectation value is 10.498199999999999 with variance 340.00005183999997.
# In trial 16, expectation value is 10.492080000000001 with variance 340.00100362240005.
# In trial 17, expectation value is 10.491999999999997 with variance 340.0010239999999.
# In trial 18, expectation value is 10.510900000000003 with variance 340.00190096.
# In trial 19, expectation value is 10.500460000000002 with variance 340.00000338560005.
# In trial 20, expectation value is 10.497500000000002 with variance 340.00010000000015.
#
# -----100000 rolls-----
# 3 occurs with probability mean 0.45769999999999994%, variance 8.166200000000002e-07, and StDev 0.0009036702938572232.
# 4 occurs with probability mean 1.40155%, variance 2.972094999999998e-06, and StDev 0.001723976507960592.
# 5 occurs with probability mean 2.7696500000000004%, variance 3.407855e-06, and StDev 0.001846037648586832.
# 6 occurs with probability mean 4.64645%, variance 1.0301495000000014e-05, and StDev 0.003209594211111432.
# 7 occurs with probability mean 6.9269%, variance 8.658579999999984e-06, and StDev 0.0029425465161998688.
# 8 occurs with probability mean 9.7596%, variance 1.9288680000000002e-05, and StDev 0.004391887976713432.
# 9 occurs with probability mean 11.54655%, variance 2.234829500000006e-05, and StDev 0.004727398333121513.
# 10 occurs with probability mean 12.510250000000001%, variance 1.985257499999989e-05, and StDev 0.004455622852082511.
# 11 occurs with probability mean 12.465649999999998%, variance 1.7556654999999984e-05, and StDev 0.004190066228593527.
# 12 occurs with probability mean 11.630700000000001%, variance 2.6342019999999957e-05, and StDev 0.005132447759110652.
# 13 occurs with probability mean 9.70825%, variance 1.7737574999999996e-05, and StDev 0.004211600052236679.
# 14 occurs with probability mean 6.9261%, variance 1.2013379999999984e-05, and StDev 0.0034660323137558867.
# 15 occurs with probability mean 4.634%, variance 1.1578400000000004e-05, and StDev 0.003402704806473815.
# 16 occurs with probability mean 2.7750999999999997%, variance 6.196180000000002e-06, and StDev 0.0024892127269480206.
# 17 occurs with probability mean 1.37815%, variance 2.881654999999998e-06, and StDev 0.0016975438138675531.
# 18 occurs with probability mean 0.46340000000000003%, variance 7.004800000000008e-07, and StDev 0.0008369468322420492.
# In trial 1, expectation value is 10.496129999999999 with variance 340.0002396304.
# In trial 2, expectation value is 10.48927 with variance 340.0018421264.
# In trial 3, expectation value is 10.499469999999999 with variance 340.00000449439995.
# In trial 4, expectation value is 10.50303 with variance 340.0001468944.
# In trial 5, expectation value is 10.482689999999996 with variance 340.0047941776.
# In trial 6, expectation value is 10.497530000000001 with variance 340.00009761440003.
# In trial 7, expectation value is 10.50904 with variance 340.0013075456.
# In trial 8, expectation value is 10.47766 with variance 340.0079852095999.
# In trial 9, expectation value is 10.508159999999998 with variance 340.00106536960004.
# In trial 10, expectation value is 10.497729999999999 with variance 340.0000824464.
# In trial 11, expectation value is 10.49348 with variance 340.0006801664.
# In trial 12, expectation value is 10.485780000000004 with variance 340.0032353344001.
# In trial 13, expectation value is 10.520590000000004 with variance 340.0067831696.
# In trial 14, expectation value is 10.50575 with variance 340.00052900000003.
# In trial 15, expectation value is 10.507859999999999 with variance 340.00098847360005.
# In trial 16, expectation value is 10.496979999999999 with variance 340.0001459264.
# In trial 17, expectation value is 10.50357 with variance 340.00020391839996.
# In trial 18, expectation value is 10.51115 with variance 340.00198916000005.
# In trial 19, expectation value is 10.480089999999999 with variance 340.00634252960003.
# In trial 20, expectation value is 10.50151 with variance 340.0000364816.
#
# -----500000 rolls-----
# 3 occurs with probability mean 0.46406%, variance 1.9860080000000011e-07, and StDev 0.0004456464966764578.
# 4 occurs with probability mean 1.3897700000000002%, variance 5.044581999999996e-07, and StDev 0.000710252208725886.
# 5 occurs with probability mean 2.77631%, variance 7.966677999999992e-07, and StDev 0.0008925624908094666.
# 6 occurs with probability mean 4.6248499999999995%, variance 7.281349999999964e-07, and StDev 0.0008533082678610329.
# 7 occurs with probability mean 6.93997%, variance 1.933346200000014e-06, and StDev 0.0013904482011207803.
# 8 occurs with probability mean 9.73804%, variance 2.5281487999999953e-06, and StDev 0.0015900153458378932.
# 9 occurs with probability mean 11.57174%, variance 4.240672800000019e-06, and StDev 0.002059289391999099.
# 10 occurs with probability mean 12.4886%, variance 2.350408000000018e-06, and StDev 0.001533104040826981.
# 11 occurs with probability mean 12.500610000000002%, variance 2.3493557999999882e-06, and StDev 0.0015327608424017063.
# 12 occurs with probability mean 11.588130000000001%, variance 3.1747461999999803e-06, and StDev 0.0017817817486998739.
# 13 occurs with probability mean 9.71613%, variance 3.0964582000000067e-06, and StDev 0.00175967559510269.
# 14 occurs with probability mean 6.9456500000000005%, variance 2.887959000000007e-06, and StDev 0.0016993995998587285.
# 15 occurs with probability mean 4.63274%, variance 1.6912648000000064e-06, and StDev 0.001300486370555265.
# 16 occurs with probability mean 2.77436%, variance 1.1571567999999971e-06, and StDev 0.0010757122291765568.
# 17 occurs with probability mean 1.3856%, variance 5.504480000000001e-07, and StDev 0.0007419218287663466.
# 18 occurs with probability mean 0.46343999999999996%, variance 2.0490880000000007e-07, and StDev 0.00045266853215128624.
# In trial 1, expectation value is 10.504756 with variance 340.0003619125761.
# In trial 2, expectation value is 10.504197999999999 with variance 340.000281971264.
# In trial 3, expectation value is 10.508912 with variance 340.001270779904.
# In trial 4, expectation value is 10.499168 with variance 340.000011075584.
# In trial 5, expectation value is 10.502322 with variance 340.000086266944.
# In trial 6, expectation value is 10.50055 with variance 340.00000484000003.
# In trial 7, expectation value is 10.488638 with variance 340.002065520704.
# In trial 8, expectation value is 10.499792000000001 with variance 340.00000069222403.
# In trial 9, expectation value is 10.50029 with variance 340.0000013456.
# In trial 10, expectation value is 10.49708 with variance 340.00013642240003.
# In trial 11, expectation value is 10.495519999999999 with variance 340.00032112640014.
# In trial 12, expectation value is 10.502075999999999 with variance 340.000068956416.
# In trial 13, expectation value is 10.495930000000001 with variance 340.0002650384001.
# In trial 14, expectation value is 10.499906 with variance 340.000000141376.
# In trial 15, expectation value is 10.500233999999999 with variance 340.000000876096.
# In trial 16, expectation value is 10.495002000000001 with variance 340.000399680064.
# In trial 17, expectation value is 10.499724 with variance 340.00000121881595.
# In trial 18, expectation value is 10.502265999999999 with variance 340.000082156096.
# In trial 19, expectation value is 10.498690000000002 with variance 340.00002745759997.
# In trial 20, expectation value is 10.50269 with variance 340.00011577759994.
#
# -----1000000 rolls-----
# 3 occurs with probability mean 0.46403%, variance 5.940420000000002e-08, and StDev 0.0002437297683911426.
# 4 occurs with probability mean 1.389935%, variance 2.442865499999994e-07, and StDev 0.000494253528060245.
# 5 occurs with probability mean 2.77544%, variance 3.122808000000009e-07, and StDev 0.0005588209015418097.
# 6 occurs with probability mean 4.632075%, variance 7.046337499999924e-07, and StDev 0.0008394246541530648.
# 7 occurs with probability mean 6.9357299999999995%, variance 1.2328521999999938e-06, and StDev 0.001110338777130653.
# 8 occurs with probability mean 9.716895000000001%, variance 2.0888349500000052e-06, and StDev 0.001445280232342505.
# 9 occurs with probability mean 11.571155%, variance 1.6124169499999804e-06, and StDev 0.0012698098085933895.
# 10 occurs with probability mean 12.496595%, variance 1.4682249499999749e-06, and StDev 0.0012117033259011773.
# 11 occurs with probability mean 12.516665%, variance 1.1174805500000206e-06, and StDev 0.0010571095260189555.
# 12 occurs with probability mean 11.582514999999999%, variance 1.5933245499999955e-06, and StDev 0.0012622696027394446.
# 13 occurs with probability mean 9.71926%, variance 1.2983487999999959e-06, and StDev 0.001139451095922943.
# 14 occurs with probability mean 6.944875000000001%, variance 1.0148197500000075e-06, and StDev 0.0010073826234356079.
# 15 occurs with probability mean 4.62398%, variance 4.89825200000002e-07, and StDev 0.0006998751317199391.
# 16 occurs with probability mean 2.784105%, variance 4.3101094999999984e-07, and StDev 0.0006565142420389674.
# 17 occurs with probability mean 1.38473%, variance 2.4682419999999944e-07, and StDev 0.000496814049720818.
# 18 occurs with probability mean 0.462015%, variance 8.818655000000015e-08, and StDev 0.0002969622029821306.
# In trial 1, expectation value is 10.505361 with variance 340.000459845136.
# In trial 2, expectation value is 10.498897999999999 with variance 340.0000194304641.
# In trial 3, expectation value is 10.500362 with variance 340.000002096704.
# In trial 4, expectation value is 10.494527999999999 with variance 340.00047908454405.
# In trial 5, expectation value is 10.49918 with variance 340.0000107584.
# In trial 6, expectation value is 10.497304 with variance 340.0001162946561.
# In trial 7, expectation value is 10.500169 with variance 340.000000456976.
# In trial 8, expectation value is 10.50087 with variance 340.0000121104.
# In trial 9, expectation value is 10.499273000000002 with variance 340.000008456464.
# In trial 10, expectation value is 10.500983999999999 with variance 340.00001549209594.
# In trial 11, expectation value is 10.495484999999999 with variance 340.0003261636.
# In trial 12, expectation value is 10.498762000000003 with variance 340.000024522304.
# In trial 13, expectation value is 10.505511000000002 with variance 340.00048593793605.
# In trial 14, expectation value is 10.502643999999998 with variance 340.000111851776.
# In trial 15, expectation value is 10.499965 with variance 340.00000001959995.
# In trial 16, expectation value is 10.503385999999999 with variance 340.000183439936.
# In trial 17, expectation value is 10.497806 with variance 340.00007701817606.
# In trial 18, expectation value is 10.500822999999997 with variance 340.000010837264.
# In trial 19, expectation value is 10.501837000000002 with variance 340.000053993104.
# In trial 20, expectation value is 10.502307999999998 with variance 340.000085229824.
#
# -----5000000 rolls-----
# 3 occurs with probability mean 0.462494%, variance 1.7812647999999983e-08, and StDev 0.00013346403260804007.
# 4 occurs with probability mean 1.389019%, variance 5.376595799999992e-08, and StDev 0.00023187487574120644.
# 5 occurs with probability mean 2.780507%, variance 1.8421970200000116e-07, and StDev 0.00042920822685498606.
# 6 occurs with probability mean 4.630083%, variance 1.804540220000027e-07, and StDev 0.00042479880178739054.
# 7 occurs with probability mean 6.9435899999999995%, variance 1.2909283999999993e-07, and StDev 0.00035929492064319516.
# 8 occurs with probability mean 9.721846%, variance 3.735788880000073e-07, and StDev 0.0006112110012098991.
# 9 occurs with probability mean 11.571298999999998%, variance 5.068314779999967e-07, and StDev 0.0007119209773563332.
# 10 occurs with probability mean 12.500161000000002%, variance 4.2080331799998584e-07, and StDev 0.0006486935470620821.
# 11 occurs with probability mean 12.495802%, variance 3.2392855200000816e-07, and StDev 0.0005691472146993325.
# 12 occurs with probability mean 11.577588%, variance 3.6159075200000024e-07, and StDev 0.0006013241654881336.
# 13 occurs with probability mean 9.724511%, variance 2.745023579999988e-07, and StDev 0.0005239297262038095.
# 14 occurs with probability mean 6.945116%, variance 4.963078080000041e-07, and StDev 0.0007044911695685079.
# 15 occurs with probability mean 4.632746%, variance 1.557660880000016e-07, and StDev 0.00039467212721447863.
# 16 occurs with probability mean 2.7749859999999997%, variance 1.0706584800000122e-07, and StDev 0.0003272091808002966.
# 17 occurs with probability mean 1.38785%, variance 3.4371240000000166e-08, and StDev 0.00018539482193416344.
# 18 occurs with probability mean 0.462402%, variance 2.0063272000000073e-08, and StDev 0.0001416448798933448.
# In trial 1, expectation value is 10.500206599999999 with variance 340.000000682937.
# In trial 2, expectation value is 10.4997328 with variance 340.0000011423334.
# In trial 3, expectation value is 10.498962800000001 with variance 340.0000172125413.
# In trial 4, expectation value is 10.497743600000002 with variance 340.00008146145535.
# In trial 5, expectation value is 10.499647399999997 with variance 340.0000019892281.
# In trial 6, expectation value is 10.500290999999999 with variance 340.00000135489597.
# In trial 7, expectation value is 10.4989742 with variance 340.0000168362503.
# In trial 8, expectation value is 10.501447 with variance 340.000033500944.
# In trial 9, expectation value is 10.497665 with variance 340.00008723559995.
# In trial 10, expectation value is 10.498860599999999 with variance 340.0000207717178.
# In trial 11, expectation value is 10.5001254 with variance 340.00000025160256.
# In trial 12, expectation value is 10.500758000000003 with variance 340.000009193024.
# In trial 13, expectation value is 10.501816799999997 with variance 340.0000528121958.
# In trial 14, expectation value is 10.4991768 with variance 340.0000108425318.
# In trial 15, expectation value is 10.500226 with variance 340.000000817216.
# In trial 16, expectation value is 10.498758799999997 with variance 340.0000246492391.
# In trial 17, expectation value is 10.5023904 with variance 340.0000914241946.
# In trial 18, expectation value is 10.501096199999997 with variance 340.000019226471.
# In trial 19, expectation value is 10.502314799999999 with variance 340.00008573278467.
# In trial 20, expectation value is 10.498323199999998 with variance 340.00004498653186.
#
# -----10000000 rolls-----
# 3 occurs with probability mean 0.4633145%, variance 6.258589499999966e-09, and StDev 7.911124762004431e-05.
# 4 occurs with probability mean 1.3897745000000001%, variance 1.4755929500000133e-08, and StDev 0.00012147398692724354.
# 5 occurs with probability mean 2.7780384999999996%, variance 6.15939054999996e-08, and StDev 0.00024818119489598644.
# 6 occurs with probability mean 4.629591%, variance 7.004959799999883e-08, and StDev 0.00026466884591881765.
# 7 occurs with probability mean 6.945228500000001%, variance 1.4851250549999784e-07, and StDev 0.0003853732028826055.
# 8 occurs with probability mean 9.718836999999999%, variance 1.562094419999995e-07, and StDev 0.0003952334019285307.
# 9 occurs with probability mean 11.575603000000001%, variance 2.3220494200000318e-07, and StDev 0.0004818764800236708.
# 10 occurs with probability mean 12.501702%, variance 2.2781631199999698e-07, and StDev 0.00047730107060428535.
# 11 occurs with probability mean 12.5000985%, variance 1.7468190550000133e-07, and StDev 0.000417949644694192.
# 12 occurs with probability mean 11.576173%, variance 2.315669020000056e-07, and StDev 0.0004812139877435044.
# 13 occurs with probability mean 9.718506%, variance 8.719778800000121e-08, and StDev 0.0002952927157923155.
# 14 occurs with probability mean 6.9461065%, variance 9.719742550000228e-08, and StDev 0.00031176501647876126.
# 15 occurs with probability mean 4.6268115000000005%, variance 8.74459254999978e-08, and StDev 0.00029571257244154805.
# 16 occurs with probability mean 2.7773725%, variance 4.2108357499999956e-08, and StDev 0.00020520321025753948.
# 17 occurs with probability mean 1.389362%, variance 1.767239199999995e-08, and StDev 0.0001329375492477575.
# 18 occurs with probability mean 0.463481%, variance 6.682717999999961e-09, and StDev 8.174789293920645e-05.
# In trial 1, expectation value is 10.499926699999998 with variance 340.00000008596624.
# In trial 2, expectation value is 10.4990297 with variance 340.0000150637135.
# In trial 3, expectation value is 10.49883 with variance 340.0000219024.
# In trial 4, expectation value is 10.4995971 with variance 340.00000259725454.
# In trial 5, expectation value is 10.500637 with variance 340.000006492304.
# In trial 6, expectation value is 10.497539699999999 with variance 340.00009684921747.
# In trial 7, expectation value is 10.4989899 with variance 340.0000163248322.
# In trial 8, expectation value is 10.501107699999999 with variance 340.0000196319886.
# In trial 9, expectation value is 10.500226300000001 with variance 340.00000081938697.
# In trial 10, expectation value is 10.5006885 with variance 340.000007584516.
# In trial 11, expectation value is 10.4997148 with variance 340.0000013014246.
# In trial 12, expectation value is 10.4997009 with variance 340.000001431373.
# In trial 13, expectation value is 10.499848799999999 with variance 340.0000003657831.
# In trial 14, expectation value is 10.4984035 with variance 340.000040780996.
# In trial 15, expectation value is 10.500011899999999 with variance 340.00000000226584.
# In trial 16, expectation value is 10.500066499999999 with variance 340.000000070756.
# In trial 17, expectation value is 10.499686699999998 with variance 340.0000015705102.
# In trial 18, expectation value is 10.501540299999998 with variance 340.0000379603854.
# In trial 19, expectation value is 10.5014352 with variance 340.0000329567846.
# In trial 20, expectation value is 10.4999579 with variance 340.0000000283586.
